# %%
import pandas as pd  # importing the pandas library
dataset = pd.read_excel('/content/data_NB_classification.xlsx') # import the data using Pandas function
X_train = dataset[['Experience','Tenure','Perf_Score','Rating','Job_Nature']] # creation of X
y_train = dataset['Attrition']
from sklearn.naive_bayes import GaussianNB
y_pred = GaussianNB().fit(X_train, y_train).predict(X_train) # calculating the predicted values
print(y_pred)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
